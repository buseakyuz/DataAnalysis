# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("jobs_in_data.csv")
df
# Out:
#       work_year                 job_title                    job_category  \
# 0          2023      Data DevOps Engineer                Data Engineering
# 1          2023            Data Architect  Data Architecture and Modeling
# 2          2023            Data Architect  Data Architecture and Modeling
# 3          2023            Data Scientist       Data Science and Research
# 4          2023            Data Scientist       Data Science and Research
# ...         ...                       ...                             ...
# 9350       2021           Data Specialist    Data Management and Strategy
# 9351       2020            Data Scientist       Data Science and Research
# 9352       2021  Principal Data Scientist       Data Science and Research
# 9353       2020            Data Scientist       Data Science and Research
# 9354       2020     Business Data Analyst                   Data Analysis
#
#      salary_currency  salary  salary_in_usd employee_residence  \
# ...

# %%
df.head()
# Out:
#    work_year             job_title                    job_category  \
# 0       2023  Data DevOps Engineer                Data Engineering
# 1       2023        Data Architect  Data Architecture and Modeling
# 2       2023        Data Architect  Data Architecture and Modeling
# 3       2023        Data Scientist       Data Science and Research
# 4       2023        Data Scientist       Data Science and Research
#
#   salary_currency  salary  salary_in_usd employee_residence experience_level  \
# 0             EUR   88000          95012            Germany        Mid-level
# 1             USD  186000         186000      United States           Senior
# 2             USD   81800          81800      United States           Senior
# 3             USD  212000         212000      United States           Senior
# 4             USD   93300          93300      United States           Senior
#
#   employment_type work_setting company_location company_size
# ...

# %%
df.tail()
# Out:
#       work_year                 job_title                  job_category  \
# 9350       2021           Data Specialist  Data Management and Strategy
# 9351       2020            Data Scientist     Data Science and Research
# 9352       2021  Principal Data Scientist     Data Science and Research
# 9353       2020            Data Scientist     Data Science and Research
# 9354       2020     Business Data Analyst                 Data Analysis
#
#      salary_currency  salary  salary_in_usd employee_residence  \
# 9350             USD  165000         165000      United States
# 9351             USD  412000         412000      United States
# 9352             USD  151000         151000      United States
# 9353             USD  105000         105000      United States
# 9354             USD  100000         100000      United States
#
#      experience_level employment_type work_setting company_location  \
# 9350           Senior       Full-time       Remote    United States
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9355 entries, 0 to 9354
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           9355 non-null   int64
#  1   job_title           9355 non-null   object
#  2   job_category        9355 non-null   object
#  3   salary_currency     9355 non-null   object
#  4   salary              9355 non-null   int64
#  5   salary_in_usd       9355 non-null   int64
#  6   employee_residence  9355 non-null   object
#  7   experience_level    9355 non-null   object
#  8   employment_type     9355 non-null   object
#  9   work_setting        9355 non-null   object
#  10  company_location    9355 non-null   object
#  11  company_size        9355 non-null   object
# dtypes: int64(3), object(9)
# memory usage: 877.2+ KB

# %%
df.describe()
# Out:
#          work_year         salary  salary_in_usd
# count  9355.000000    9355.000000    9355.000000
# mean   2022.760449  149927.981293  150299.495564
# std       0.519470   63608.835387   63177.372024
# min    2020.000000   14000.000000   15000.000000
# 25%    2023.000000  105200.000000  105700.000000
# 50%    2023.000000  143860.000000  143000.000000
# 75%    2023.000000  187000.000000  186723.000000
# max    2023.000000  450000.000000  450000.000000

# %%
df.isnull().any()
# Out:
# work_year             False
# job_title             False
# job_category          False
# salary_currency       False
# salary                False
# salary_in_usd         False
# employee_residence    False
# experience_level      False
# employment_type       False
# work_setting          False
# company_location      False
# company_size          False
# dtype: bool

# %%
df.isnull().sum()
# Out:
# work_year             0
# job_title             0
# job_category          0
# salary_currency       0
# salary                0
# salary_in_usd         0
# employee_residence    0
# experience_level      0
# employment_type       0
# work_setting          0
# company_location      0
# company_size          0
# dtype: int64

# %%
df.head()
# Out:
#    work_year             job_title                    job_category  \
# 0       2023  Data DevOps Engineer                Data Engineering
# 1       2023        Data Architect  Data Architecture and Modeling
# 2       2023        Data Architect  Data Architecture and Modeling
# 3       2023        Data Scientist       Data Science and Research
# 4       2023        Data Scientist       Data Science and Research
#
#   salary_currency  salary  salary_in_usd employee_residence experience_level  \
# 0             EUR   88000          95012            Germany        Mid-level
# 1             USD  186000         186000      United States           Senior
# 2             USD   81800          81800      United States           Senior
# 3             USD  212000         212000      United States           Senior
# 4             USD   93300          93300      United States           Senior
#
#   employment_type work_setting company_location company_size
# ...

# %%
#work_year
df["work_year"].unique()
# Out:
# array([2023, 2022, 2020, 2021])

# %%
df["work_year"].value_counts()
# Out:
# work_year
# 2023    7453
# 2022    1634
# 2021     197
# 2020      71
# Name: count, dtype: int64

# %%
df.groupby("work_year")[["salary_in_usd"]].mean().reset_index()
# Out:
#    work_year  salary_in_usd
# 0       2020  105878.859155
# 1       2021  106483.644670
# 2       2022  135467.501836
# 3       2023  155132.591708

# %%
#job_title
df["job_title"].unique()
# Out:
# array(['Data DevOps Engineer', 'Data Architect', 'Data Scientist',
#        'Machine Learning Researcher', 'Data Engineer',
#        'Machine Learning Engineer', 'Data Analyst', 'Analytics Engineer',
#        'Applied Scientist', 'BI Developer',
#        'Business Intelligence Engineer', 'Research Scientist',
#        'Research Analyst', 'Research Engineer', 'Data Science Engineer',
#        'Data Quality Analyst', 'Data Product Manager',
#        'Machine Learning Scientist', 'AI Engineer', 'MLOps Engineer',
#        'Deep Learning Engineer', 'Data Modeler', 'Data Product Owner',
#        'Data Science Consultant', 'Business Intelligence Analyst',
#        'AI Developer', 'Data Manager', 'ML Engineer',
#        'Data Science Director', 'Head of Data', 'BI Analyst',
#        'Data Management Analyst', 'Machine Learning Modeler',
#        'Data Specialist', 'BI Data Analyst', 'Data Integration Engineer',
#        'Business Intelligence Manager', 'Data Integration Specialist',
# ...

# %%
#job_category
df["job_category"].unique()
# Out:
# array(['Data Engineering', 'Data Architecture and Modeling',
#        'Data Science and Research', 'Machine Learning and AI',
#        'Data Analysis', 'Leadership and Management',
#        'BI and Visualization', 'Data Quality and Operations',
#        'Data Management and Strategy', 'Cloud and Database'], dtype=object)

# %%
df.head()
# Out:
#    work_year             job_title                    job_category  \
# 0       2023  Data DevOps Engineer                Data Engineering
# 1       2023        Data Architect  Data Architecture and Modeling
# 2       2023        Data Architect  Data Architecture and Modeling
# 3       2023        Data Scientist       Data Science and Research
# 4       2023        Data Scientist       Data Science and Research
#
#   salary_currency  salary  salary_in_usd employee_residence experience_level  \
# 0             EUR   88000          95012            Germany        Mid-level
# 1             USD  186000         186000      United States           Senior
# 2             USD   81800          81800      United States           Senior
# 3             USD  212000         212000      United States           Senior
# 4             USD   93300          93300      United States           Senior
#
#   employment_type work_setting company_location company_size
# ...

# %%
df.groupby("job_category")[["salary_in_usd"]].mean().reset_index()
# Out:
#                      job_category  salary_in_usd
# 0            BI and Visualization  135092.102236
# 1              Cloud and Database  155000.000000
# 2                   Data Analysis  108505.721345
# 3  Data Architecture and Modeling  156002.359073
# 4                Data Engineering  146197.656195
# 5    Data Management and Strategy  103139.934426
# 6     Data Quality and Operations  100879.472727
# 7       Data Science and Research  163758.575979
# 8       Leadership and Management  145476.019881
# 9         Machine Learning and AI  178925.847339

# %%
df.groupby("job_category")[["salary_in_usd"]].mean().reset_index().sort_values(by="salary_in_usd",ascending=False)
# Out:
#                      job_category  salary_in_usd
# 9         Machine Learning and AI  178925.847339
# 7       Data Science and Research  163758.575979
# 3  Data Architecture and Modeling  156002.359073
# 1              Cloud and Database  155000.000000
# 4                Data Engineering  146197.656195
# 8       Leadership and Management  145476.019881
# 0            BI and Visualization  135092.102236
# 2                   Data Analysis  108505.721345
# 5    Data Management and Strategy  103139.934426
# 6     Data Quality and Operations  100879.472727

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
group_category_salary = df.groupby("job_category")[["salary_in_usd"]].mean().reset_index()

plt.figure(figsize=(18,5))
plt.bar(x = "job_category", height = "salary_in_usd", data = group_category_salary)
plt.xticks(rotation=90);

# %%
plt.figure(figsize=(18,5))
sns.barplot(x = "job_category", y = "salary_in_usd", data = group_category_salary)
plt.xticks(rotation=90);

# %%
df.head()
# Out:
#    work_year             job_title                    job_category  \
# 0       2023  Data DevOps Engineer                Data Engineering
# 1       2023        Data Architect  Data Architecture and Modeling
# 2       2023        Data Architect  Data Architecture and Modeling
# 3       2023        Data Scientist       Data Science and Research
# 4       2023        Data Scientist       Data Science and Research
#
#   salary_currency  salary  salary_in_usd employee_residence experience_level  \
# 0             EUR   88000          95012            Germany        Mid-level
# 1             USD  186000         186000      United States           Senior
# 2             USD   81800          81800      United States           Senior
# 3             USD  212000         212000      United States           Senior
# 4             USD   93300          93300      United States           Senior
#
#   employment_type work_setting company_location company_size
# ...

# %%
plt.figure(figsize=(15,6))

sns.boxplot(x = "job_category", y = "salary_in_usd",data=df)
# Out:
# <Axes: xlabel='job_category', ylabel='salary_in_usd'>

# %%
year_category_salary = df.groupby(["work_year","job_category"])[["salary_in_usd"]].mean().reset_index()
year_category_salary
# Out:
#     work_year                    job_category  salary_in_usd
# 0        2020                   Data Analysis   68014.666667
# 1        2020                Data Engineering   94575.823529
# 2        2020       Data Science and Research  129538.827586
# 3        2020         Machine Learning and AI  113276.400000
# 4        2021                   Data Analysis   87818.500000
# 5        2021  Data Architecture and Modeling  169940.600000
# 6        2021                Data Engineering  107192.288889
# 7        2021    Data Management and Strategy  165000.000000
# 8        2021       Data Science and Research  107517.819444
# 9        2021       Leadership and Management  131892.888889
# 10       2021         Machine Learning and AI  101396.891892
# 11       2022            BI and Visualization  100875.000000
# 12       2022              Cloud and Database  175000.000000
# 13       2022                   Data Analysis  107384.224913
# ...

# %%
plt.figure(figsize=(19,5))
sns.lineplot( x = "job_category", y = "salary_in_usd",hue = "work_year",data = year_category_salary)
plt.xticks(rotation=90);

# %%
plt.figure(figsize=(19,5))
sns.barplot( x = "job_category", y = "salary_in_usd",hue = "work_year",data = year_category_salary)
plt.xticks(rotation=90);

# %%
df.groupby("job_category")[["salary_in_usd"]].agg(["mean","max","min"]).reset_index()
# Out:
#                      job_category  salary_in_usd
#                                             mean     max     min
# 0            BI and Visualization  135092.102236  259900   15000
# 1              Cloud and Database  155000.000000  190000  115000
# 2                   Data Analysis  108505.721345  430967   15000
# 3  Data Architecture and Modeling  156002.359073  376080   52500
# 4                Data Engineering  146197.656195  385000   18000
# 5    Data Management and Strategy  103139.934426  250000   46400
# 6     Data Quality and Operations  100879.472727  289120   23753
# 7       Data Science and Research  163758.575979  450000   16000
# 8       Leadership and Management  145476.019881  430640   20000
# 9         Machine Learning and AI  178925.847339  423000   15000

# %%
#salary_currency
df["salary_currency"].unique()
# Out:
# array(['EUR', 'USD', 'GBP', 'CAD', 'AUD', 'PLN', 'BRL', 'TRY', 'CHF',
#        'SGD', 'DKK'], dtype=object)

# %%
df["salary_currency"].value_counts()
# Out:
# salary_currency
# USD    8591
# GBP     347
# EUR     340
# CAD      38
# AUD      11
# PLN       7
# SGD       6
# CHF       5
# BRL       4
# TRY       3
# DKK       3
# Name: count, dtype: int64

# %%
df[df["salary_currency"]=="TRY"]
# Out:
#       work_year       job_title               job_category salary_currency  \
# 4194       2023      BI Analyst       BI and Visualization             TRY
# 9247       2021  Data Scientist  Data Science and Research             TRY
# 9257       2021   Data Engineer           Data Engineering             TRY
#
#       salary  salary_in_usd employee_residence experience_level  \
# 4194  360000          18381             Turkey           Senior
# 9247  180000          20171             Turkey           Senior
# 9257  250000          28016             Turkey        Mid-level
#
#      employment_type work_setting company_location company_size
# 4194       Full-time       Remote           Turkey            L
# 9247       Full-time       Hybrid           Turkey            L
# 9257       Full-time       Remote           Turkey            M

# %%
df[(df["job_title"]=="Data Scientist")&(df["experience_level"]=="Senior")&(df["work_year"]==2021)]
# Out:
#       work_year       job_title               job_category salary_currency  \
# 9187       2021  Data Scientist  Data Science and Research             EUR
# 9226       2021  Data Scientist  Data Science and Research             USD
# 9228       2021  Data Scientist  Data Science and Research             CAD
# 9247       2021  Data Scientist  Data Science and Research             TRY
# 9251       2021  Data Scientist  Data Science and Research             EUR
# 9266       2021  Data Scientist  Data Science and Research             USD
# 9319       2021  Data Scientist  Data Science and Research             CAD
#
#       salary  salary_in_usd employee_residence experience_level  \
# 9187   45000          53192             France           Senior
# 9226  165000         165000      United States           Senior
# 9228  130000         103691             Canada           Senior
# 9247  180000          20171             Turkey           Senior
# ...

# %%
#salary
df["salary"].max()
# Out:
# np.int64(450000)

# %%
#employee_residence
df["employee_residence"].unique()
# Out:
# array(['Germany', 'United States', 'United Kingdom', 'Canada', 'Spain',
#        'Ireland', 'South Africa', 'Poland', 'France', 'Czech Republic',
#        'Netherlands', 'Pakistan', 'Ukraine', 'Lithuania', 'Portugal',
#        'Australia', 'Uganda', 'Colombia', 'Italy', 'Slovenia', 'Romania',
#        'Greece', 'India', 'Latvia', 'Mauritius', 'Armenia', 'Croatia',
#        'Thailand', 'South Korea', 'Estonia', 'Turkey', 'Philippines',
#        'Brazil', 'Qatar', 'Russia', 'Kenya', 'Tunisia', 'Ghana',
#        'Belgium', 'Switzerland', 'Andorra', 'Ecuador', 'Peru', 'Mexico',
#        'Moldova', 'Nigeria', 'Saudi Arabia', 'Argentina', 'Egypt',
#        'Uzbekistan', 'Georgia', 'Central African Republic', 'Finland',
#        'Austria', 'Singapore', 'Sweden', 'Kuwait', 'Cyprus',
#        'Bosnia and Herzegovina', 'Iran', 'American Samoa', 'China',
#        'Costa Rica', 'Chile', 'Puerto Rico', 'Denmark', 'Bolivia',
#        'Dominican Republic', 'Indonesia', 'United Arab Emirates',
# ...

# %%
df.head()
# Out:
#    work_year             job_title                    job_category  \
# 0       2023  Data DevOps Engineer                Data Engineering
# 1       2023        Data Architect  Data Architecture and Modeling
# 2       2023        Data Architect  Data Architecture and Modeling
# 3       2023        Data Scientist       Data Science and Research
# 4       2023        Data Scientist       Data Science and Research
#
#   salary_currency  salary  salary_in_usd employee_residence experience_level  \
# 0             EUR   88000          95012            Germany        Mid-level
# 1             USD  186000         186000      United States           Senior
# 2             USD   81800          81800      United States           Senior
# 3             USD  212000         212000      United States           Senior
# 4             USD   93300          93300      United States           Senior
#
#   employment_type work_setting company_location company_size
# ...

# %%
#experience_level
df["experience_level"].unique()
# Out:
# array(['Mid-level', 'Senior', 'Executive', 'Entry-level'], dtype=object)

# %%
df.groupby("experience_level")[["salary_in_usd"]].mean().reset_index()
# Out:
#   experience_level  salary_in_usd
# 0      Entry-level   88534.776210
# 1        Executive  189462.914591
# 2        Mid-level  117523.918138
# 3           Senior  162356.126099

# %%
experience_salary = df.groupby(["experience_level","job_category"])[["salary_in_usd"]].mean().reset_index()
experience_salary
# Out:
#    experience_level                    job_category  salary_in_usd
# 0       Entry-level            BI and Visualization   85928.571429
# 1       Entry-level                   Data Analysis   69962.300000
# 2       Entry-level                Data Engineering   96347.663158
# 3       Entry-level    Data Management and Strategy   91003.846154
# 4       Entry-level     Data Quality and Operations   36627.000000
# 5       Entry-level       Data Science and Research  100975.951220
# 6       Entry-level       Leadership and Management   81012.300000
# 7       Entry-level         Machine Learning and AI   89076.390625
# 8         Executive            BI and Visualization  185566.666667
# 9         Executive                   Data Analysis  110156.250000
# 10        Executive  Data Architecture and Modeling  167500.000000
# 11        Executive                Data Engineering  187123.273585
# 12        Executive       Data Science and Research  206460.246914
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(18,5))
sns.barplot(x = "job_category",y = "salary_in_usd",hue="experience_level",data=experience_salary)
plt.title("Salary by Job Category")
plt.xlabel("Job Category")
plt.ylabel("Salary")
plt.legend(loc="upper right")
plt.xticks(rotation=90);

# %%
df.head()
# Out:
#    work_year             job_title                    job_category  \
# 0       2023  Data DevOps Engineer                Data Engineering
# 1       2023        Data Architect  Data Architecture and Modeling
# 2       2023        Data Architect  Data Architecture and Modeling
# 3       2023        Data Scientist       Data Science and Research
# 4       2023        Data Scientist       Data Science and Research
#
#   salary_currency  salary  salary_in_usd employee_residence experience_level  \
# 0             EUR   88000          95012            Germany        Mid-level
# 1             USD  186000         186000      United States           Senior
# 2             USD   81800          81800      United States           Senior
# 3             USD  212000         212000      United States           Senior
# 4             USD   93300          93300      United States           Senior
#
#   employment_type work_setting company_location company_size
# ...

# %%
#employement type
df["employment_type"].unique()
# Out:
# array(['Full-time', 'Part-time', 'Contract', 'Freelance'], dtype=object)

# %%
df["employment_type"].value_counts()
# Out:
# employment_type
# Full-time    9310
# Contract       19
# Part-time      15
# Freelance      11
# Name: count, dtype: int64

# %%
#work setting
df["work_setting"].unique()
# Out:
# array(['Hybrid', 'In-person', 'Remote'], dtype=object)

# %%
df["work_setting"].value_counts()
# Out:
# work_setting
# In-person    5730
# Remote       3434
# Hybrid        191
# Name: count, dtype: int64

# %%
df.groupby(["work_year","work_setting"])[["job_title"]].count().reset_index()
# Out:
#     work_year work_setting  job_title
# 0        2020       Hybrid         20
# 1        2020    In-person         16
# 2        2020       Remote         35
# 3        2021       Hybrid         64
# 4        2021    In-person         26
# 5        2021       Remote        107
# 6        2022       Hybrid         54
# 7        2022    In-person        708
# 8        2022       Remote        872
# 9        2023       Hybrid         53
# 10       2023    In-person       4980
# 11       2023       Remote       2420

# %%
#company_size
df["company_size"].unique()
# Out:
# array(['L', 'M', 'S'], dtype=object)

# %%
df["company_size"].value_counts()
# Out:
# company_size
# M    8448
# L     748
# S     159
# Name: count, dtype: int64

# %%
df.groupby(["company_size","experience_level"])[["job_title"]].count().reset_index()
# Out:
#    company_size experience_level  job_title
# 0             L      Entry-level        105
# 1             L        Executive         18
# 2             L        Mid-level        166
# 3             L           Senior        459
# 4             M      Entry-level        346
# 5             M        Executive        256
# 6             M        Mid-level       1644
# 7             M           Senior       6202
# 8             S      Entry-level         45
# 9             S        Executive          7
# 10            S        Mid-level         59
# 11            S           Senior         48

# %%
size_experience = df.groupby(["company_size","experience_level"])[["job_title"]].count().reset_index()

plt.figure(figsize=(12,5))
sns.barplot(x = "company_size", y="job_title",hue="experience_level",data = size_experience )
# Out:
# <Axes: xlabel='company_size', ylabel='job_title'>

# %%
s_size = df[df["company_size"]=="S"]
s_size.head()
# Out:
#       work_year                job_title               job_category  \
# 209        2023             Data Analyst              Data Analysis
# 564        2023         Research Analyst  Data Science and Research
# 610        2023  Data Science Consultant  Data Science and Research
# 1827       2023           Data Scientist  Data Science and Research
# 2086       2020      Azure Data Engineer           Data Engineering
#
#      salary_currency  salary  salary_in_usd employee_residence  \
# 209              GBP   30000          36912     United Kingdom
# 564              USD  100000         100000      United States
# 610              USD   21000          21000           Pakistan
# 1827             CAD  130000          96313             Canada
# 2086             USD  100000         100000          Mauritius
#
#      experience_level employment_type work_setting company_location  \
# 209            Senior       Full-time       Remote   United Kingdom
# ...

# %%
s_size["experience_level"].value_counts()
# Out:
# experience_level
# Mid-level      59
# Senior         48
# Entry-level    45
# Executive       7
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    work_year             job_title                    job_category  \
# 0       2023  Data DevOps Engineer                Data Engineering
# 1       2023        Data Architect  Data Architecture and Modeling
# 2       2023        Data Architect  Data Architecture and Modeling
# 3       2023        Data Scientist       Data Science and Research
# 4       2023        Data Scientist       Data Science and Research
#
#   salary_currency  salary  salary_in_usd employee_residence experience_level  \
# 0             EUR   88000          95012            Germany        Mid-level
# 1             USD  186000         186000      United States           Senior
# 2             USD   81800          81800      United States           Senior
# 3             USD  212000         212000      United States           Senior
# 4             USD   93300          93300      United States           Senior
#
#   employment_type work_setting company_location company_size
# ...

# %%
df["job_category"].unique()
# Out:
# array(['Data Engineering', 'Data Architecture and Modeling',
#        'Data Science and Research', 'Machine Learning and AI',
#        'Data Analysis', 'Leadership and Management',
#        'BI and Visualization', 'Data Quality and Operations',
#        'Data Management and Strategy', 'Cloud and Database'], dtype=object)

# %%
df_data_science_research = df[df["job_category"]=="Data Science and Research"]
df_data_science_research
# Out:
#       work_year                 job_title               job_category  \
# 3          2023            Data Scientist  Data Science and Research
# 4          2023            Data Scientist  Data Science and Research
# 5          2023            Data Scientist  Data Science and Research
# 6          2023            Data Scientist  Data Science and Research
# 13         2023            Data Scientist  Data Science and Research
# ...         ...                       ...                        ...
# 9346       2021  Director of Data Science  Data Science and Research
# 9347       2021            Data Scientist  Data Science and Research
# 9351       2020            Data Scientist  Data Science and Research
# 9352       2021  Principal Data Scientist  Data Science and Research
# 9353       2020            Data Scientist  Data Science and Research
#
#      salary_currency  salary  salary_in_usd employee_residence  \
# 3                USD  212000         212000      United States
# ...

# %%
df_data_science_research["job_title"].value_counts()
# Out:
# job_title
# Data Scientist                        1989
# Applied Scientist                      272
# Research Scientist                     269
# Research Engineer                      144
# Data Science Manager                    88
# Data Science Consultant                 44
# Research Analyst                        39
# Decision Scientist                      38
# Director of Data Science                29
# Data Science Lead                       20
# Data Science Engineer                   14
# Applied Data Scientist                  11
# Head of Data Science                    11
# Data Science Practitioner               10
# Principal Data Scientist                10
# Lead Data Scientist                      8
# AI Research Engineer                     4
# Data Science Director                    4
# Machine Learning Research Engineer       4
# Staff Data Scientist                     2
# Data Scientist Lead                      2
# ...

# %%
data_science_df = df_data_science_research[df_data_science_research["job_title"]=="Data Scientist"]
data_science_df
# Out:
#       work_year       job_title               job_category salary_currency  \
# 3          2023  Data Scientist  Data Science and Research             USD
# 4          2023  Data Scientist  Data Science and Research             USD
# 5          2023  Data Scientist  Data Science and Research             USD
# 6          2023  Data Scientist  Data Science and Research             USD
# 13         2023  Data Scientist  Data Science and Research             GBP
# ...         ...             ...                        ...             ...
# 9342       2020  Data Scientist  Data Science and Research             USD
# 9343       2020  Data Scientist  Data Science and Research             USD
# 9347       2021  Data Scientist  Data Science and Research             SGD
# 9351       2020  Data Scientist  Data Science and Research             USD
# 9353       2020  Data Scientist  Data Science and Research             USD
#
#       salary  salary_in_usd employee_residence experience_level  \
# ...

# %%
data_science_df.groupby("experience_level")[["salary_in_usd"]].mean()
# Out:
#                   salary_in_usd
# experience_level
# Entry-level        88406.000000
# Executive         188563.066667
# Mid-level         116281.877676
# Senior            168716.961688
